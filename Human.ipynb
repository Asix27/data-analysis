# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_csv('human_data.csv')
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
sns.countplot(y=df.dtypes ,data=df)
plt.xlabel("count of each data type")
plt.ylabel("data types")
plt.show()

# %%
x = df.EmpSatisfaction
y = df.Salary

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.boxplot(x='GenderID',y='Salary',data=df)
# Out:
# <Axes: xlabel='GenderID', ylabel='Salary'>

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='EmpSatisfaction', hue='MarriedID', data=df)
# Out:
# <Axes: xlabel='EmpSatisfaction', ylabel='count'>

# %%
pd.set_option('display.max_columns', None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 0            1       5            4                       0   62506      0
# 1            5       3            3                       0  104437      1
# 2            5       5            3                       0   64955      1
# 3            1       5            3                       0   64991      0
# 4            5       5            3                       0   50825      1
#
# ...

# %%
#Предобработка
from sklearn.preprocessing import LabelEncoder

# Создание объекта LabelEncoder
label_encoder = LabelEncoder()

# Применение Label Encoding к колонке "RaceDesc"
RaceDesc_Encoded = label_encoder.fit_transform(df['RaceDesc'])
race_desc_series = pd.Series(RaceDesc_Encoded, name='RaceDesc_Encoded')

features_name = [
    'MarriedID', 'MaritalStatusID', 'EmpStatusID', 'DeptID', 'PerfScoreID', 
    'FromDiversityJobFairID', 'Salary', 'Termd', 'PositionID', 
    'GenderID', 
    'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount', 
    'DaysLateLast30', 'Absences'
]

new_df = pd.concat([df[features_name],race_desc_series], axis=1)

new_df.shape
new_df
# Out:
#      MarriedID  MaritalStatusID  EmpStatusID  DeptID  PerfScoreID  \
# 0            0                0            1       5            4
# 1            1                1            5       3            3
# 2            1                1            5       5            3
# 3            1                1            1       5            3
# 4            0                2            5       5            3
# ..         ...              ...          ...     ...          ...
# 306          0                0            1       5            3
# 307          0                0            5       5            1
# 308          0                0            1       3            4
# 309          0                0            1       3            3
# 310          0                4            1       5            3
#
#      FromDiversityJobFairID  Salary  Termd  PositionID  ManagerID  GenderID  \
# 0                         0   62506      0          19       22.0         1
# ...

# %%
sns.countplot(y=new_df.dtypes ,data=new_df)
plt.xlabel("count of each data type")
plt.ylabel("data types")
plt.show()

# %%
sns.boxplot(x='GenderID',y='Salary',data=new_df)
# Out:
# <Axes: xlabel='GenderID', ylabel='Salary'>

# %%
sns.boxplot(x='FromDiversityJobFairID',y='Salary',data=new_df)
# Out:
# <Axes: xlabel='FromDiversityJobFairID', ylabel='Salary'>

# %%
X.plot(x='RaceDesc_Encoded', y='Salary', style='o')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\asix2\OneDrive\Рабочий стол\Git\data-analysis\Human.ipynb Ячейка 13 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/asix2/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/Git/data-analysis/Human.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> X.plot(x='RaceDesc_Encoded', y='Salary', style='o')
#       <a href='vscode-notebook-cell:/c%3A/Users/asix2/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/Git/data-analysis/Human.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# NameError: name 'X' is not defined

# %%
new_df.plot(x='SpecialProjectsCount', y='Salary', style='o')
plt.show()

# %%
X.plot(x='EngagementSurvey', y='Salary', style='o')
plt.show()

# %%
# Расчет среднего уровня вовлеченности для каждого ManagerID
mean_engagement = df.groupby('ManagerID')['EngagementSurvey'].mean().reset_index()

# Визуализация среднего уровня вовлеченности
plt.figure(figsize=(10,7))
sns.barplot(x='ManagerID', y='EngagementSurvey', data=mean_engagement)
plt.title('Средний уровень вовлеченности по менеджерам')
plt.show()

# Для расчета медианы просто замените .mean() на .median()
median_engagement = df.groupby('ManagerID')['EngagementSurvey'].median().reset_index()

# Визуализация медианного уровня вовлеченности
plt.figure(figsize=(10,7))
sns.barplot(x='ManagerID', y='EngagementSurvey', data=median_engagement)
plt.title('Медианный уровень вовлеченности по менеджерам')
plt.show()

# %%
# Расчет среднего уровня опоздание
mean_engagement = new_df.groupby('RaceDesc_Encoded')['Absences'].mean().reset_index()

# Визуализация среднего уровня опоздание
plt.figure(figsize=(10,7))
sns.barplot(x='RaceDesc_Encoded', y='Absences', data=mean_engagement)
plt.title('Средний уровень вовлеченности по менеджерам')
plt.show()

# Расчет мединаны опоздание
median_engagement = new_df.groupby('RaceDesc_Encoded')['Absences'].median().reset_index()

# Визуализация медианного уровня опоздание
plt.figure(figsize=(10,7))
sns.barplot(x='RaceDesc_Encoded', y='Absences', data=median_engagement)
plt.title('Медианный уровень вовлеченности по менеджерам')
plt.show()

# %%
corr = new_df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
new_df.plot(x='SpecialProjectsCount', y='Salary', style='o')
plt.show()

# %%
from sklearn import linear_model
regression_model = linear_model.LinearRegression()

X = df[['SpecialProjectsCount']]
y = df['Salary']

regression_model.fit(X, y)

plt.scatter(X, y, color='red', marker='+')
plt.xlabel('Salary')
plt.ylabel('SpecialProjectsCount')
plt.plot(X, regression_model.predict(X), color='blue')

# %%
from sklearn import linear_model
regression_model = linear_model.LinearRegression()

X = df[['PerfScoreID']]
y = df['EngagementSurvey']

regression_model.fit(X, y)

plt.scatter(X, y, color='red', marker='+')
plt.xlabel('PerfScoreID')
plt.ylabel('EngagementSurvey')
plt.plot(X, regression_model.predict(X), color='blue')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MarriedID               311 non-null    int64
#  1   MaritalStatusID         311 non-null    int64
#  2   EmpStatusID             311 non-null    int64
#  3   DeptID                  311 non-null    int64
#  4   PerfScoreID             311 non-null    int64
#  5   FromDiversityJobFairID  311 non-null    int64
#  6   Salary                  311 non-null    int64
#  7   Termd                   311 non-null    int64
#  8   PositionID              311 non-null    int64
#  9   ManagerID               303 non-null    float64
#  10  GenderID                311 non-null    int64
#  11  EngagementSurvey        311 non-null    float64
#  12  EmpSatisfaction         311 non-null    int64
#  13  SpecialProjectsCount    311 non-null    int64
# ...

# %%
new_df.isnull().sum()
# Out:
# MarriedID                 0
# MaritalStatusID           0
# EmpStatusID               0
# DeptID                    0
# PerfScoreID               0
# FromDiversityJobFairID    0
# Salary                    0
# Termd                     0
# PositionID                0
# ManagerID                 8
# GenderID                  0
# EngagementSurvey          0
# EmpSatisfaction           0
# SpecialProjectsCount      0
# DaysLateLast30            0
# Absences                  0
# RaceDesc_Encoded          0
# dtype: int64

# %%
X = new_df[["EngagementSurvey"]]
Y = new_df["Termd"]

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score 
model = LogisticRegression()
model.fit(X, Y)
survival_status = model.predict(X)
accuracy = accuracy_score(Y,survival_status)
slope = model.coef_

# %%
print(slope)
# Out:
# [[-0.04579674]]

# %%
accuracy
# Out:
# 0.6655948553054662

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(Y, survival_status)
print(confusion_matrix)
# Out:
# [[207   0]
#  [104   0]]
